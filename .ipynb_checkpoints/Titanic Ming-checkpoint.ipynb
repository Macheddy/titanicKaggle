# %%
import pandas as pd
def load_csv(csv):
    return pd.read_csv(csv)

TRAIN = "train.csv"
TEST = "test.csv"
GENDER_SUB = "gender_submission.csv"

# %%
trainDF = load_csv(TRAIN)
trainDF.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
trainDF.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib as plt
# %matplotlib inline

# %%
trainDF.hist(bins=50, figsize=(13, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f472e0a2400>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f472d944668>]], dtype=object)

# %%
trainDF["Fare"].where(trainDF["Fare"] < 200, 200, inplace=False).hist(bins=50, figsize=(13,10))

# %%
# show gender and fare paid
richPeopleDF = trainDF[["Age", "SibSp", "Parch", "Sex","Fare", "Survived", "Pclass", "Cabin"]][trainDF["Fare"] > 100]

# %%
print(richPeopleDF.count() / (testDF.count() + trainDF.count()))
print("================================")
print(richPeopleDF[richPeopleDF["Survived"] == 0])
# print(trainDF.count() + testDF.count())
# Out:
# Age            0.045889
# Cabin          0.145763
# Embarked            NaN
# Fare           0.040520
# Name                NaN
# Parch          0.040489
# PassengerId         NaN
# Pclass         0.040489
# Sex            0.040489
# SibSp          0.040489
# Survived            NaN
# Ticket              NaN
# dtype: float64
# ...
#       Age  SibSp  Parch     Sex      Fare  Survived  Pclass        Cabin
# 27   19.0      3      2    male  263.0000         0       1  C23 C25 C27
# 118  24.0      0      1    male  247.5208         0       1      B58 B60
# 297   2.0      1      2  female  151.5500         0       1      C22 C26
# 332  38.0      0      1    male  153.4625         0       1          C91
# 373  22.0      0      0    male  135.6333         0       1          NaN
# 377  27.0      0      2    male  211.5000         0       1          C82
# 438  64.0      1      4    male  263.0000         0       1  C23 C25 C27
# ...

# %%
import matplotlib as plt
# %matplotlib inline

# %%
def transformGender(gender):
    if gender == 'male':
        return 0
    else:
        return 1
    

trainDF["GenderID"] = trainDF["Sex"].apply(transformGender)
trainDF.select_dtypes(include=['int']).corr(method="pearson", min_periods=1)
# Out:
#              PassengerId  Survived    Pclass     SibSp     Parch  GenderID
# PassengerId     1.000000 -0.005007 -0.035144 -0.057527 -0.001652 -0.042939
# Survived       -0.005007  1.000000 -0.338481 -0.035322  0.081629  0.543351
# Pclass         -0.035144 -0.338481  1.000000  0.083081  0.018443 -0.131900
# SibSp          -0.057527 -0.035322  0.083081  1.000000  0.414838  0.114631
# Parch          -0.001652  0.081629  0.018443  0.414838  1.000000  0.245489
# GenderID       -0.042939  0.543351 -0.131900  0.114631  0.245489  1.000000

# %%
trainDFNumberOnly = trainDF.select_dtypes(include=['int'])
trainDFNumberOnly
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch  GenderID
# 0              1         0       3      1      0         0
# 1              2         1       1      1      0         1
# 2              3         1       3      0      0         1
# 3              4         1       1      1      0         1
# 4              5         0       3      0      0         0
# 5              6         0       3      0      0         0
# 6              7         0       1      0      0         0
# 7              8         0       3      3      1         0
# 8              9         1       3      0      2         1
# 9             10         1       2      1      0         1
# 10            11         1       3      1      1         1
# 11            12         1       1      0      0         1
# 12            13         0       3      0      0         0
# 13            14         0       3      1      5         0
# 14            15         0       3      0      0         1
# ...

# %%
import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

plot_corr(trainDFNumberOnly)

# %%
plot_corr()

# %%
trainDF
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
trainDF["Fare"].hist(bins=100)

# %%
testDF = load_csv(TEST)
testDF.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
genderSubDF = load_csv(GENDER_SUB)
genderSubDF.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
ax = CabinCrew[CabinCrew.Survived != True][CabinCrew.Sex == "male"].plot(kind='scatter', x="Fare", y='Age', color='Red', label='Dead-Male')



ax = CabinCrew[CabinCrew.Survived != True][CabinCrew.Sex == "female"].plot(kind='scatter', x="Fare", y='Age', color='DarkRed', label='Dead-Female', ax=ax)

ax = CabinCrew[CabinCrew.Survived != False][CabinCrew.Sex == "female"].plot(kind='scatter', x="Fare", y='Age', color='DarkGreen', label='Alive-Female', ax=ax)


ax = CabinCrew[CabinCrew.Survived != False][CabinCrew.Sex == "male"].plot(kind='scatter', x="Fare", y='Age', color='Green', label='Alive-Male', ax=ax)
